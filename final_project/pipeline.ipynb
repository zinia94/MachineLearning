# %% [markdown]
# <a href="https://colab.research.google.com/github/zinia94/MachineLearning/blob/main/final_project/pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# # Business Problem Definition

# %% [markdown]
# # Data Collection
